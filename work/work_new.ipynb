# %%
import data as data_processing
import plot as plot_data
import pandas as pd

# %%
data=pd.read_excel("../data/data.xlsx")
data=data.iloc[:,1:]

# %%
name='Data 12'

border=data_processing.get_index_start_end_work(data,name)
start_=border[0][0]
end_=border[0][1]

data_test=data_processing.get_data_by_border(data,start_,end_,name)

data_test=data_processing.get_data_with_frequency(data_test,1)
plot_data.plot(data_test)
